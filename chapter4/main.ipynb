# %% [markdown]
# # SVM
#
# Destek Vektör Makinesi / Support Vector Machine (SVM), doğrusal veya doğrusal olmayan sınıflandırma, regresyon ve hatta aykırı değer tespiti yapabilen güçlü ve çok yönlü bir Makine Öğrenimi modelidir. Makine Öğreniminde en popüler modellerden biridir ve Makine Öğrenimi ile ilgilenen herkesin araç setinde bulunması gerekir. SVM'ler özellikle küçük veya orta boyutlu karmaşık veri kümelerinin sınıflandırılması için çok uygundur.
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %%
import numpy as np 
from sklearn import datasets
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler 
from sklearn.svm import LinearSVC
from sklearn.datasets import make_moons
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures
from sklearn.svm import SVC

# %%
iris = datasets.load_iris()
X = iris["data"][:, (2, 3)]
y = (iris["target"] == 2).astype(np.float64)

svm_clf = Pipeline([
    ("scaler", StandardScaler()),
    ("linear_svc", LinearSVC(C = 1, loss = "hinge")),
])

svm_clf.fit(X, y)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('linear_svc', LinearSVC(C=1, loss='hinge'))])

# %%
svm_clf.predict([[5.5, 1.7]])
# Out:
# array([1.])

# %%
X, y = make_moons(n_samples=100, noise=0.15)
polynominal_svm_clf = Pipeline([
    ("poly_features", PolynomialFeatures(degree = 3)),
    ("scaler", StandardScaler()),
    ("svm_clf", LinearSVC(C = 10, loss = "hinge")),
])

polynominal_svm_clf.fit(X, y)
# Out:
# Pipeline(steps=[('poly_features', PolynomialFeatures(degree=3)),
#                 ('scaler', StandardScaler()),
#                 ('svm_clf', LinearSVC(C=10, loss='hinge'))])

# %%
poly_kernel_svm_clf = Pipeline([
    ("scaler", StandardScaler()),
    ("svm_clf", SVC(kernel = "poly", degree = 3, coef0 =  1, C = 5))
])

poly_kernel_svm_clf.fit(X, y)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm_clf', SVC(C=5, coef0=1, kernel='poly'))])

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
rbf_kernel_svm_clf = Pipeline([
    ("scaler", StandardScaler()),
    ("svm_clf", SVC(kernel = "rbf", gamma = 5, C = 0.001))
])

rbf_kernel_svm_clf.fit(X, y)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm_clf', SVC(C=0.001, gamma=5))])

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# SVM Regression

# %%
from sklearn.svm import LinearSVR

svm_reg = LinearSVR(epsilon = 1.5)
svm_reg.fit(X, y)
# Out:
# LinearSVR(epsilon=1.5)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sklearn.svm import SVR 

svm_poly_reg = SVR(kernel="poly", degree=2, C=100, epsilon=0.1)
svm_poly_reg.fit(X, y)
# Out:
# SVR(C=100, degree=2, kernel='poly')
